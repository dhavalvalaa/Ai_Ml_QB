# %% [markdown]
# # Extract

# %% [markdown]
# ## Extract data from csv file

# %%
import kagglehub
nilaychauhan_world_bank_datasets_path = kagglehub.dataset_download('nilaychauhan/world-bank-datasets')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
import pandas as pd

# %%
df_projects = pd.read_csv('world-bank-datasets\projects_data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\3723353446.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df_projects = pd.read_csv('world-bank-datasets\projects_data.csv')
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\3723353446.py:1: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_projects = pd.read_csv('world-bank-datasets\projects_data.csv')

# %%
display(df_projects.head())
# Out:
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# ...

# %%
df_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18248 entries, 0 to 18247
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        18248 non-null  object
#  1   regionname                18248 non-null  object
#  2   countryname               18248 non-null  object
#  3   prodline                  18248 non-null  object
#  4   lendinginstr              18002 non-null  object
#  5   lendinginstrtype          18002 non-null  object
#  6   envassesmentcategorycode  12437 non-null  object
#  7   supplementprojectflg      18195 non-null  object
#  8   productlinetype           18248 non-null  object
#  9   projectstatusdisplay      18244 non-null  object
#  10  status                    18244 non-null  object
#  11  project_name              18248 non-null  object
#  12  boardapprovaldate         16744 non-null  object
# ...

# %%
df_projects.isnull().sum()
# Out:
# id                              0
# regionname                      0
# countryname                     0
# prodline                        0
# lendinginstr                  246
# lendinginstrtype              246
# envassesmentcategorycode     5811
# supplementprojectflg           53
# productlinetype                 0
# projectstatusdisplay            4
# status                          4
# project_name                    0
# boardapprovaldate            1504
# board_approval_month         1504
# closingdate                  3349
# lendprojectcost               125
# ibrdcommamt                     0
# idacommamt                      0
# totalamt                        0
# grantamt                        0
# borrower                     5919
# impagency                    6097
# url                             0
# projectdoc                  18248
# majorsector_percent         18248
# sector1                         0
# sector2                      8721
# ...

# %%
print(df_projects.isnull().sum(axis=1).to_string())
# Out:
# 0        35
# 1        34
# 2        36
# 3        32
# 4        23
# 5        33
# 6        34
# 7        33
# 8        34
# 9        33
# 10       34
# 11       36
# 12       35
# 13       36
# 14       35
# 15       33
# 16       36
# 17       34
# 18       33
# 19       33
# 20       35
# 21       33
# 22       33
# 23       36
# 24       35
# 25       30
# 26       30
# 27       35
# 28       33
# 29       29
# 30       33
# 31       35
# 32       30
# 33       35
# 34       33
# 35       36
# 36       36
# 37       20
# 38       32
# 39       34
# 40       36
# 41       34
# 42       36
# 43       33
# 44       36
# 45       29
# 46       31
# 47       25
# 48       33
# 49       34
# 50       34
# 51       36
# 52       34
# 53       28
# 54       32
# 55       23
# 56       20
# 57       28
# 58       36
# 59       23
# 60       35
# 61       36
# 62       26
# 63       24
# 64       21
# 65       30
# 66       34
# 67       24
# 68       28
# 69       34
# 70       28
# ...

# %%
df_projects.shape
# Out:
# (18248, 57)

# %%
f = open("world-bank-datasets\population_data.csv")
for i in range(10):
    line = f.readline()
    print('line: ', i, line)
f.close()
# Out:
# line:  0 ï»¿"Data Source","World Development Indicators",
#
# line:  1
#
# line:  2 "Last Updated Date","2018-06-28",
#
# line:  3
#
# line:  4 "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",
#
# ...

# %% [markdown]
# The skiprows=4 parameter in pd.read_csv() tells pandas to skip the first 4 rows of the CSV file when reading it.
#
# This is especially useful when the top rows contain metadata, notes, or headers you don’t want in your dataset.

# %%
df_population = pd.read_csv('world-bank-datasets\population_data.csv', skiprows=4)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\2818506338.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df_population = pd.read_csv('world-bank-datasets\population_data.csv', skiprows=4)

# %%
print(df_population.head().to_string())
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960       1961       1962       1963       1964       1965        1966        1967        1968        1969        1970        1971        1972        1973        1974        1975        1976        1977        1978        1979        1980        1981        1982        1983        1984        1985        1986        1987        1988        1989        1990        1991        1992        1993        1994        1995        1996        1997        1998        1999        2000        2001        2002        2003        2004        2005        2006        2007        2008        2009        2010        2011        2012        2013        2014        2015        2016        2017  Unnamed: 62
# ...

# %%
df_population.dropna(how='all', inplace=True, axis=1)

# %%
df_population.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              4
#                  ..
# 2013              2
# 2014              2
# 2015              2
# 2016              2
# 2017              2
# Length: 62, dtype: int64

# %%
df_population.shape
# Out:
# (264, 62)

# %% [markdown]
# ## Read json

# %%
df_json = pd.read_json('world-bank-datasets\population_data.json',orient='records')
df_json.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\1846845032.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df_json = pd.read_json('world-bank-datasets\population_data.json',orient='records')
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2008  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101353.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  27294031.0
# ...

# %% [markdown]
# ## Extract data from Sql databases

# %%
import sqlite3
conn = sqlite3.connect('world-bank-datasets\population_data.db')
pd.read_sql('SELECT * FROM population_data', conn)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\3915493826.py:2: SyntaxWarning: invalid escape sequence '\p'
#   conn = sqlite3.connect('world-bank-datasets\population_data.db')
#      index  Country_Name Country_Code     Indicator_Name Indicator_Code  \
# 0        0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1        1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2        2        Angola          AGO  Population, total    SP.POP.TOTL
# 3        3       Albania          ALB  Population, total    SP.POP.TOTL
# 4        4       Andorra          AND  Population, total    SP.POP.TOTL
# ..     ...           ...          ...                ...            ...
# 259    259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260    260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# ...

# %%
print(pd.read_sql("PRAGMA table_info(population_data);", conn).to_string())
# Out:
#     cid            name     type  notnull dflt_value  pk
# 0     0           index  INTEGER        0       None   0
# 1     1    Country_Name     TEXT        0       None   0
# 2     2    Country_Code     TEXT        0       None   0
# 3     3  Indicator_Name     TEXT        0       None   0
# 4     4  Indicator_Code     TEXT        0       None   0
# 5     5            1960     REAL        0       None   0
# 6     6            1961     REAL        0       None   0
# 7     7            1962     REAL        0       None   0
# 8     8            1963     REAL        0       None   0
# 9     9            1964     REAL        0       None   0
# 10   10            1965     REAL        0       None   0
# 11   11            1966     REAL        0       None   0
# 12   12            1967     REAL        0       None   0
# 13   13            1968     REAL        0       None   0
# 14   14            1969     REAL        0       None   0
# ...

# %% [markdown]
# ### sql.db to csv

# %%
import pandas as pd
import sqlite3

# Connect to your SQLite database
conn = sqlite3.connect('world-bank-datasets/population_data.db')

# Read the table into a DataFrame
df = pd.read_sql("SELECT * FROM population_data;", conn)

# Save it as a CSV file
df.to_csv('try_to_convert.csv', index=False)

# Close the connection
conn.close()

# %% [markdown]
# # Transform

# %% [markdown]
# ### combining data

# %%
f = open("world-bank-datasets/rural_population_percent.csv")
for i in range(10):
    line = f.readline()
    print('line: ', i, line)
f.close()
# Out:
# line:  0 ï»¿"Data Source","World Development Indicators",
#
# line:  1
#
# line:  2 "Last Updated Date","2018-06-28",
#
# line:  3
#
# line:  4 "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",
#
# ...

# %% [markdown]
# ahiya 4 line meta data in che atle skiprows = 4 aavse

# %%
df_rural = pd.read_csv('world-bank-datasets/rural_population_percent.csv', skiprows=4)
df_rural.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Rural population (% of total population)
# 1  Afghanistan          AFG  Rural population (% of total population)
# 2       Angola          AGO  Rural population (% of total population)
# 3      Albania          ALB  Rural population (% of total population)
# 4      Andorra          AND  Rural population (% of total population)
#
#    Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# 0  SP.RUR.TOTL.ZS  49.224  49.239  49.254  49.270  49.285  49.300  ...
# 1  SP.RUR.TOTL.ZS  91.779  91.492  91.195  90.890  90.574  90.250  ...
# 2  SP.RUR.TOTL.ZS  89.565  89.202  88.796  88.376  87.942  87.496  ...
# 3  SP.RUR.TOTL.ZS  69.295  69.057  68.985  68.914  68.842  68.770  ...
# 4  SP.RUR.TOTL.ZS  41.550  39.017  36.538  34.128  31.795  29.555  ...
#
#      2009    2010    2011    2012    2013    2014    2015    2016    2017  \
# ...

# %%
f = open("world-bank-datasets/electricity_access_percent.csv")
for i in range(10):
    line = f.readline()
    print('line : ', i , line)
f.close()
# Out:
# line :  0 ï»¿"Data Source","World Development Indicators",
#
# line :  1
#
# line :  2 "Last Updated Date","2018-06-28",
#
# line :  3
#
# line :  4 "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",
#
# ...

# %%
df_electricity = pd.read_csv("world-bank-datasets/electricity_access_percent.csv", skiprows=4)
df_electricity.head(7)
# Out:
#            Country Name Country Code                           Indicator Name  \
# 0                 Aruba          ABW  Access to electricity (% of population)
# 1           Afghanistan          AFG  Access to electricity (% of population)
# 2                Angola          AGO  Access to electricity (% of population)
# 3               Albania          ALB  Access to electricity (% of population)
# 4               Andorra          AND  Access to electricity (% of population)
# 5            Arab World          ARB  Access to electricity (% of population)
# 6  United Arab Emirates          ARE  Access to electricity (% of population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...        2009  \
# 0  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   93.354546
# 1  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   44.854885
# 2  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   32.382469
# ...

# %%
print(df_rural.isnull().sum().to_string())
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                5
# 1961                5
# 1962                5
# 1963                5
# 1964                5
# 1965                5
# 1966                5
# 1967                5
# 1968                5
# 1969                5
# 1970                5
# 1971                5
# 1972                5
# 1973                5
# 1974                5
# 1975                5
# 1976                5
# 1977                5
# 1978                5
# 1979                5
# 1980                5
# 1981                5
# 1982                5
# 1983                5
# 1984                5
# 1985                5
# 1986                5
# 1987                5
# 1988                5
# 1989                5
# 1990                3
# 1991                3
# 1992                3
# 1993                3
# 1994                3
# 1995                3
# 1996                3
# ...

# %%
df_rural.sample(10)
# Out:
#                                      Country Name Country Code  \
# 229  Europe & Central Asia (IDA & IBRD countries)          TEC
# 37                                          Chile          CHL
# 175                                        Norway          NOR
# 254                         Virgin Islands (U.S.)          VIR
# 67                                        Eritrea          ERI
# 46                                     Costa Rica          CRI
# 261                                  South Africa          ZAF
# 2                                          Angola          AGO
# 95                                       Honduras          HND
# 93                                    High income          HIC
#
#                                Indicator Name  Indicator Code       1960  \
# 229  Rural population (% of total population)  SP.RUR.TOTL.ZS  54.987879
# 37   Rural population (% of total population)  SP.RUR.TOTL.ZS  32.164000
# ...

# %%
df_rural.dropna(how='all', axis=1, inplace=True)
df
# Out:
#      index  Country_Name Country_Code     Indicator_Name Indicator_Code  \
# 0        0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1        1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2        2        Angola          AGO  Population, total    SP.POP.TOTL
# 3        3       Albania          ALB  Population, total    SP.POP.TOTL
# 4        4       Andorra          AND  Population, total    SP.POP.TOTL
# ..     ...           ...          ...                ...            ...
# 259    259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260    260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 261    261  South Africa          ZAF  Population, total    SP.POP.TOTL
# 262    262        Zambia          ZMB  Population, total    SP.POP.TOTL
# 263    263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
#            1960        1961        1962        1963        1964  ...  \
# ...

# %%
print(df_electricity.isnull().sum().to_string())
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              264
# 1961              264
# 1962              264
# 1963              264
# 1964              264
# 1965              264
# 1966              264
# 1967              264
# 1968              264
# 1969              264
# 1970              264
# 1971              264
# 1972              264
# 1973              264
# 1974              264
# 1975              264
# 1976              264
# 1977              264
# 1978              264
# 1979              264
# 1980              264
# 1981              264
# 1982              264
# 1983              264
# 1984              264
# 1985              264
# 1986              264
# 1987              264
# 1988              264
# 1989              264
# 1990               13
# 1991               13
# 1992               13
# 1993               13
# 1994               12
# 1995                9
# 1996                8
# ...

# %%
df_electricity.shape
# Out:
# (264, 63)

# %%
df_electricity.drop(['Unnamed: 62'],axis=1, inplace=True)
df_electricity
# Out:
#      Country Name Country Code                           Indicator Name  \
# 0           Aruba          ABW  Access to electricity (% of population)
# 1     Afghanistan          AFG  Access to electricity (% of population)
# 2          Angola          AGO  Access to electricity (% of population)
# 3         Albania          ALB  Access to electricity (% of population)
# 4         Andorra          AND  Access to electricity (% of population)
# ..            ...          ...                                      ...
# 259        Kosovo          XKX  Access to electricity (% of population)
# 260   Yemen, Rep.          YEM  Access to electricity (% of population)
# 261  South Africa          ZAF  Access to electricity (% of population)
# 262        Zambia          ZMB  Access to electricity (% of population)
# 263      Zimbabwe          ZWE  Access to electricity (% of population)
#
#      Indicator Code  1960  1961  1962  1963  1964  1965  ...        2008  \
# ...

# %%
df_electricity.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Access to electricity (% of population)
# 1  Afghanistan          AFG  Access to electricity (% of population)
# 2       Angola          AGO  Access to electricity (% of population)
# 3      Albania          ALB  Access to electricity (% of population)
# 4      Andorra          AND  Access to electricity (% of population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...        2008  \
# 0  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   93.086166
# 1  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   42.400000
# 2  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   31.268013
# 3  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.000000
# 4  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.000000
#
#          2009        2010        2011        2012        2013        2014  \
# ...

# %%
print(df_rural.columns.equals(df_electricity))
print(df_rural.columns)
print(df_rural.columns)
# Out:
# False
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017'],
#       dtype='object')
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
# ...

# %%
df = pd.concat([df_rural, df_electricity])

# %%
df.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Rural population (% of total population)
# 1  Afghanistan          AFG  Rural population (% of total population)
# 2       Angola          AGO  Rural population (% of total population)
# 3      Albania          ALB  Rural population (% of total population)
# 4      Andorra          AND  Rural population (% of total population)
#
#    Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# 0  SP.RUR.TOTL.ZS  49.224  49.239  49.254  49.270  49.285  49.300  ...
# 1  SP.RUR.TOTL.ZS  91.779  91.492  91.195  90.890  90.574  90.250  ...
# 2  SP.RUR.TOTL.ZS  89.565  89.202  88.796  88.376  87.942  87.496  ...
# 3  SP.RUR.TOTL.ZS  69.295  69.057  68.985  68.914  68.842  68.770  ...
# 4  SP.RUR.TOTL.ZS  41.550  39.017  36.538  34.128  31.795  29.555  ...
#
#      2008    2009    2010    2011    2012    2013    2014    2015    2016  \
# ...

# %%
df.shape
# Out:
# (528, 62)

# %% [markdown]
# ### cleaning data

# %%
df_population.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2008  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101353.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  27294031.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  21759420.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2947314.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83861.0
#
#          2009        2010        2011        2012        2013        2014  \
# ...

# %%
df_population[['Country Name', 'Country Code']]
# Out:
#      Country Name Country Code
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
# [264 rows x 2 columns]

# %%
print(df_population[['Country Name', 'Country Code']].value_counts().to_string())
# Out:
# Country Name                                          Country Code
# Afghanistan                                           AFG             1
# Albania                                               ALB             1
# Algeria                                               DZA             1
# American Samoa                                        ASM             1
# Andorra                                               AND             1
# Angola                                                AGO             1
# Antigua and Barbuda                                   ATG             1
# Arab World                                            ARB             1
# Argentina                                             ARG             1
# Armenia                                               ARM             1
# Aruba                                                 ABW             1
# Australia                                             AUS             1
# ...

# %%
df_population[['Country Name', 'Country Code']].drop_duplicates()
# Out:
#      Country Name Country Code
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
# [264 rows x 2 columns]

# %%
print(df_population['Country Name'].unique())
# Out:
# ['Aruba' 'Afghanistan' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czech Republic' 'Germany' 'Djibouti'
#  'Dominica' 'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
#  'Europe & Central Asia (excluding high income)' 'Europe & Central Asia'
# ...

# %%
matching_indices = df_population[df_population['Country Name'].astype(str).str.contains(r'^New', regex=True, na=False)].index
print(matching_indices)
# Out:
# Index([170, 178], dtype='int64')

# %%
print(df_population.iloc[[170, 178]].to_string())
# Out:
#       Country Name Country Code     Indicator Name Indicator Code       1960       1961       1962       1963       1964       1965       1966       1967       1968       1969       1970       1971       1972       1973       1974       1975       1976       1977       1978       1979       1980       1981       1982       1983       1984       1985       1986       1987       1988       1989       1990       1991       1992       1993       1994       1995       1996       1997       1998       1999       2000       2001       2002       2003       2004       2005       2006       2007       2008       2009       2010       2011       2012       2013       2014       2015       2016       2017
# ...

# %%
df[df["Country Name"] == "New Zealand;New Zealand"]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
# Index: []
#
# [0 rows x 62 columns]

# %%
matching_indices = df_population[df_population['Country Name'].astype(str).str.contains(';', regex=True, na=False)].index
print(matching_indices)
# Out:
# Index([], dtype='int64')

# %%
mask = df["Country Name"].apply(lambda x : x.lower())
mask.value_counts()
# Out:
# Country Name
# aruba           2
# afghanistan     2
# angola          2
# albania         2
# andorra         2
#                ..
# kosovo          2
# yemen, rep.     2
# south africa    2
# zambia          2
# zimbabwe        2
# Name: count, Length: 264, dtype: int64

# %%
df[df["Country Name"].apply(lambda x: x.lower()) == "aruba"]
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Rural population (% of total population)
# 0        Aruba          ABW   Access to electricity (% of population)
#
#    Indicator Code    1960    1961    1962   1963    1964  1965  ...  \
# 0  SP.RUR.TOTL.ZS  49.224  49.239  49.254  49.27  49.285  49.3  ...
# 0  EG.ELC.ACCS.ZS     NaN     NaN     NaN    NaN     NaN   NaN  ...
#
#         2008       2009       2010       2011       2012       2013  \
# 0  56.217000  56.579000  56.941000  57.302000  57.636000  57.942000
# 0  93.086166  93.354546  93.356292  93.942375  94.255814  94.578262
#
#         2014       2015       2016    2017
# 0  58.221000  58.472000  58.696000  58.893
# 0  94.906723  95.238182  95.570145     NaN
#
# [2 rows x 62 columns]

# %% [markdown]
# ### Data Types

# %%
print(df_population.dtypes.to_string())
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
# 1961              float64
# 1962              float64
# 1963              float64
# 1964              float64
# 1965              float64
# 1966              float64
# 1967              float64
# 1968              float64
# 1969              float64
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
# 1986              float64
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# ...

# %%
keepcol = ["Country Name"]
for i in range(1960, 2018):
    keepcol.append(str(i))

df_new = df_population[df_population["Country Name"].apply(lambda x: x.lower() in ['canada', 'united states','Mexico'])]
df_new
# Out:
#       Country Name Country Code     Indicator Name Indicator Code  \
# 33          Canada          CAN  Population, total    SP.POP.TOTL
# 249  United States          USA  Population, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 33    17909009.0   18271000.0   18614000.0   18964000.0   19325000.0
# 249  180671000.0  183691000.0  186538000.0  189242000.0  191889000.0
#
#             1965  ...         2008         2009         2010         2011  \
# 33    19678000.0  ...   33245773.0   33628571.0   34005274.0   34342780.0
# 249  194303000.0  ...  304093966.0  306771529.0  309338421.0  311644280.0
#
#             2012         2013         2014         2015         2016  \
# 33    34750545.0   35152370.0   35535348.0   35832513.0   36264604.0
# 249  313993272.0  316234505.0  318622525.0  321039839.0  323405935.0
#
#             2017
# 33    36708083.0
# 249  325719178.0
#
# [2 rows x 62 columns]

# %%
df_new.sum(axis=0)[keepcol]
# Out:
# Country Name    CanadaUnited States
# 1960                    198580009.0
# 1961                    201962000.0
# 1962                    205152000.0
# 1963                    208206000.0
# 1964                    211214000.0
# 1965                    213981000.0
# 1966                    216608000.0
# 1967                    219124000.0
# 1968                    221450000.0
# 1969                    223705000.0
# 1970                    226376000.0
# 1971                    229306535.0
# 1972                    231889631.0
# 1973                    234278408.0
# 1974                    236628087.0
# 1975                    239182000.0
# 1976                    241553000.0
# 1977                    244035000.0
# 1978                    246621000.0
# 1979                    249332000.0
# 1980                    251818000.0
# 1981                    254366000.0
# 1982                    256866000.0
# 1983                    259248000.0
# 1984                    261527000.0
# ...

# %%
print(df_new.groupby(["1960"]).first().to_string())
# Out:
#               Country Name Country Code     Indicator Name Indicator Code         1961         1962         1963         1964         1965         1966         1967         1968         1969         1970         1971         1972         1973         1974         1975         1976         1977         1978         1979         1980         1981         1982         1983         1984         1985         1986         1987         1988         1989         1990         1991         1992         1993         1994         1995         1996         1997         1998         1999         2000         2001         2002         2003         2004         2005         2006         2007         2008         2009         2010         2011         2012         2013         2014         2015         2016         2017
# 1960
# ...

# %%
df_projects["boardapprovaldate"] = pd.to_datetime(df_projects["boardapprovaldate"])

# %%
display(df_projects['boardapprovaldate'])
try:
    print(df_projects['boardapprovaldate'].dt.year)
    print(df_projects['boardapprovaldate'].dt.month)
    print(df_projects['boardapprovaldate'].dt.day)
    print(df_projects['boardapprovaldate'].dt.hour)
    print(df_projects['boardapprovaldate'].dt.minute)
    print(df_projects['boardapprovaldate'].dt.second)
    print(df_projects['boardapprovaldate'].dt.day_name())
except Exception as e:
    print(e)
# Out:
# 0       2018-06-28 00:00:00+00:00
# 1       2018-06-28 00:00:00+00:00
# 2       2018-06-28 00:00:00+00:00
# 3       2018-06-27 00:00:00+00:00
# 4       2018-06-27 00:00:00+00:00
#                    ...
# 18243   1948-03-25 00:00:00+00:00
# 18244   1947-08-28 00:00:00+00:00
# 18245   1947-08-22 00:00:00+00:00
# 18246   1947-08-07 00:00:00+00:00
# 18247   1947-05-09 00:00:00+00:00
# Name: boardapprovaldate, Length: 18248, dtype: datetime64[ns, UTC]
# 0        2018.0
# 1        2018.0
# 2        2018.0
# 3        2018.0
# 4        2018.0
#           ...
# 18243    1948.0
# 18244    1947.0
# 18245    1947.0
# 18246    1947.0
# 18247    1947.0
# Name: boardapprovaldate, Length: 18248, dtype: float64
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 18243    3.0
# 18244    8.0
# 18245    8.0
# 18246    8.0
# 18247    5.0
# Name: boardapprovaldate, Length: 18248, dtype: float64
# 0        28.0
# 1        28.0
# 2        28.0
# 3        27.0
# ...

# %%
df_projects["closingdate"] = pd.to_datetime(df_projects["closingdate"])

# %%
###
# create the follwing new columns in the df_projects data frame
#
# approvalyear
# approvalday
# approvalweekday
# closingyear
# closingday
# closingweekday
#
#
###

df_projects['approvalyear'] = df_projects['boardapprovaldate'].dt.year
df_projects['approvalday'] = df_projects['boardapprovaldate'].dt.day
df_projects['approvalweekday'] = df_projects['boardapprovaldate'].dt.weekday
df_projects['closingyear'] = df_projects["closingdate"].dt.year
df_projects['closingday'] = df_projects['closingdate'].dt.day
df_projects['closingweekday'] = df_projects['closingdate'].dt.weekday

# %%
df_projects.head()
# Out:
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# ...

# %% [markdown]
# ### Imputing Data

# %% [markdown]
# Key parameters:
#
# id_vars: Columns to keep as identifiers (they won’t be unpivoted)
#
# var_name: Name of the new column for former column headers
#
# value_name: Name of the new column for values
#
# How pandas figures it out:
# id_vars='Name' → This tells pandas: “Hey, keep the Name column as is.”
#
# Everything else (like Math and Science) → Becomes part of the Subject column — because they’re the column headers being melted.
#
# Their cell values (like 90, 85, 80, 89) → Go under the new column called Marks, which you assigned using value_name='Marks'.

# %%
import matplotlib.pyplot as plt

df = pd.read_csv("world-bank-datasets/gdp_data.csv", skiprows=4)

df.columns
df.drop('Unnamed: 62', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %%
df_melt = pd.melt(df, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name='Year', value_name='GDP')

# convert year to a date time
df_melt['Year'] = pd.to_datetime(df_melt['Year'])

def plot_results(column_name):
    # plot the results for Afghanistan, Albania, and Honduras
    fig, ax = plt.subplots(figsize=(8,6))


    df_melt[(df_melt['Country Name'] == 'Afghanistan') |
            (df_melt['Country Name'] == 'Albania') |
            (df_melt['Country Name'] == 'Honduras')].groupby('Country Name').plot('Year', column_name, legend=True, ax=ax)
    ax.legend(labels=['Afghanistan', 'Albania', 'Honduras'])

plot_results('GDP')

# %% [markdown]
#  Exercise - Part 1
#
# Your first task is to calculate mean GDP for each country and fill in missing values with the country mean.

# %%
df_melt["GDP_filled"] = df_melt.groupby("Country Name")["GDP"].transform(lambda x: x.fillna(x.mean()))
df_melt
# Out:
#        Country Name Country Code     Indicator Name  Indicator Code  \
# 0             Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1       Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2            Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3           Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4           Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ...             ...          ...                ...             ...
# 15307        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 15308   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 15309  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 15310        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 15311      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#             Year           GDP    GDP_filled
# 0     1960-01-01           NaN  2.036355e+09
# 1     1960-01-01  5.377778e+08  5.377778e+08
# ...

# %%
plot_results('GDP_filled')

# %% [markdown]
# Excercise - Part 2
#
# Use the fillna forward fill method to fill in the missing data. Here is the [documentation](https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.fillna.html).
#
# The pandas fillna method has a forward fill option. For example, if you wanted to use forward fill on the GDP dataset, you could execute `df_melt['GDP'].fillna(method='ffill')`. However, there are two issues with that code.
# 1. You want to first make sure the data is sorted by year
# 2. You need to group the data by country name so that the forward fill stays within each country
#
# Write code to first sort the df_melt dataframe by year, then group by 'Country Name', and finally use the forward fill method.

# %%
df_melt["GDP_ffilled"] = df_melt.sort_values('Year').groupby(["Country Name"])["GDP"].fillna(method = 'ffill')
# Out:
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\526189151.py:1: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   df_melt["GDP_ffilled"] = df_melt.sort_values('Year').groupby(["Country Name"])["GDP"].fillna(method = 'ffill')
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\526189151.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_melt["GDP_ffilled"] = df_melt.sort_values('Year').groupby(["Country Name"])["GDP"].fillna(method = 'ffill')

# %%
plot_results("GDP_ffilled")

# %% [markdown]
# Exercise - Part 3
#
# This part is similar to Part 2, but now you will use backfill. Write code that backfills the missing GDP data.

# %%
df_melt["GDP_bfill"] = df_melt.sort_values("Year").groupby(["Country Name"])["GDP"].fillna(method = "bfill")
# Out:
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\485850997.py:1: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   df_melt["GDP_bfill"] = df_melt.sort_values("Year").groupby(["Country Name"])["GDP"].fillna(method = "bfill")
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\485850997.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_melt["GDP_bfill"] = df_melt.sort_values("Year").groupby(["Country Name"])["GDP"].fillna(method = "bfill")

# %%
plot_results("GDP_bfill")

# %%
print(df_melt["GDP_filled"].isnull().sum())
print(df_melt["GDP_bfill"].isnull().sum())
# Out:
# 464
# 571

# %%
df_melt["GDP_FF_BF"] = df_melt.sort_values("Year").groupby(["Country Name"])["GDP"].fillna(method = "ffill").fillna(method = "bfill")
df_melt["GDP_FF_BF"].isnull().sum()
# Out:
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\171001370.py:1: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   df_melt["GDP_FF_BF"] = df_melt.sort_values("Year").groupby(["Country Name"])["GDP"].fillna(method = "ffill").fillna(method = "bfill")
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\171001370.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_melt["GDP_FF_BF"] = df_melt.sort_values("Year").groupby(["Country Name"])["GDP"].fillna(method = "ffill").fillna(method = "bfill")
# np.int64(0)

# %%
plot_results("GDP_FF_BF")

# %%
df[df_projects.duplicated() == True].index
# Out:
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\1531675366.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_projects.duplicated() == True].index
# Index([], dtype='int64')

# %%
print(df_projects["totalamt"].to_string())
# Out:
# 0                    0
# 1          200,000,000
# 2           58,330,000
# 3           20,000,000
# 4          100,000,000
# 5          500,000,000
# 6          350,000,000
# 7          225,000,000
# 8          125,000,000
# 9          329,900,000
# 10         200,000,000
# 11         400,000,000
# 12                   0
# 13         150,000,000
# 14                   0
# 15         389,000,000
# 16                   0
# 17         530,000,000
# 18         350,000,000
# 19         202,000,000
# 20         300,000,000
# 21         500,000,000
# 22         493,060,000
# 23         175,000,000
# 24                   0
# 25         230,000,000
# 26          80,000,000
# 27         400,000,000
# 28         130,000,000
# 29          30,000,000
# 30          35,000,000
# 31                   0
# 32         250,000,000
# 33         200,000,000
# 34         400,000,000
# 35         110,000,000
# 36         150,000,000
# 37          74,000,000
# 38         118,000,000
# 39         465,000,000
# ...

# %%
df_projects["totalamt"] = pd.to_numeric(df_projects["totalamt"].str.replace(',',''), errors='coerce', downcast='integer')
print(df_projects["totalamt"].to_string())
# Out:
# 0                 0
# 1         200000000
# 2          58330000
# 3          20000000
# 4         100000000
# 5         500000000
# 6         350000000
# 7         225000000
# 8         125000000
# 9         329900000
# 10        200000000
# 11        400000000
# 12                0
# 13        150000000
# 14                0
# 15        389000000
# 16                0
# 17        530000000
# 18        350000000
# 19        202000000
# 20        300000000
# 21        500000000
# 22        493060000
# 23        175000000
# 24                0
# 25        230000000
# 26         80000000
# 27        400000000
# 28        130000000
# 29         30000000
# 30         35000000
# 31                0
# 32        250000000
# 33        200000000
# 34        400000000
# 35        110000000
# 36        150000000
# 37         74000000
# 38        118000000
# 39        465000000
# 40                0
# 41         50000000
# 42         90000000
# 43        100000000
# 44        130000000
# ...

# %%
df_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18248 entries, 0 to 18247
# Data columns (total 63 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        18248 non-null  object
#  1   regionname                18248 non-null  object
#  2   countryname               18248 non-null  object
#  3   prodline                  18248 non-null  object
#  4   lendinginstr              18002 non-null  object
#  5   lendinginstrtype          18002 non-null  object
#  6   envassesmentcategorycode  12437 non-null  object
#  7   supplementprojectflg      18195 non-null  object
#  8   productlinetype           18248 non-null  object
#  9   projectstatusdisplay      18244 non-null  object
#  10  status                    18244 non-null  object
#  11  project_name              18248 non-null  object
#  12  boardapprovaldate         16744 non-null  datetime64[ns, UTC]
# ...

# %%
df_projects.sample(2, random_state=1)
# Out:
#            id                    regionname  \
# 4933  P113862  Middle East and North Africa
# 8079  P067803         East Asia and Pacific
#
#                                       countryname prodline  \
# 4933          Lebanese Republic;Lebanese Republic       RE
# 8079  Republic of Indonesia;Republic of Indonesia       GM
#
#                  lendinginstr lendinginstrtype envassesmentcategorycode  \
# 4933  Emergency Recovery Loan               IN                        A
# 8079             UNIDENTIFIED               XX                        C
#
#      supplementprojectflg productlinetype projectstatusdisplay  ... Latitude  \
# 4933                    N               L               Closed  ...      NaN
# 8079                    N               L               Closed  ...      NaN
#
#      Longitude Country Unnamed: 56 approvalyear approvalday approvalweekday  \
# 4933       NaN     NaN         NaN       2009.0        10.0             1.0
# ...

# %%
df_projects["countryname"] = df_projects["countryname"].str.split(';', expand=True)[0]

# %%
df_projects.sample(2, random_state=1)
# Out:
#            id                    regionname            countryname prodline  \
# 4933  P113862  Middle East and North Africa      Lebanese Republic       RE
# 8079  P067803         East Asia and Pacific  Republic of Indonesia       GM
#
#                  lendinginstr lendinginstrtype envassesmentcategorycode  \
# 4933  Emergency Recovery Loan               IN                        A
# 8079             UNIDENTIFIED               XX                        C
#
#      supplementprojectflg productlinetype projectstatusdisplay  ... Latitude  \
# 4933                    N               L               Closed  ...      NaN
# 8079                    N               L               Closed  ...      NaN
#
#      Longitude Country Unnamed: 56 approvalyear approvalday approvalweekday  \
# 4933       NaN     NaN         NaN       2009.0        10.0             1.0
# 8079       NaN     NaN         NaN       2001.0        21.0             2.0
#
#      closingyear  closingday closingweekday
# ...

# %%
print(len(df_projects))
print(df_projects.isna().sum().to_string())
# Out:
# 18248
# id                              0
# regionname                      0
# countryname                     0
# prodline                        0
# lendinginstr                  246
# lendinginstrtype              246
# envassesmentcategorycode     5811
# supplementprojectflg           53
# productlinetype                 0
# projectstatusdisplay            4
# status                          4
# project_name                    0
# boardapprovaldate            1504
# board_approval_month         1504
# closingdate                  3349
# lendprojectcost               125
# ibrdcommamt                     0
# idacommamt                      0
# totalamt                        0
# grantamt                        0
# borrower                     5919
# impagency                    6097
# url                             0
# projectdoc                  18248
# majorsector_percent         18248
# sector1                         0
# sector2                      8721
# ...

# %%
df_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18248 entries, 0 to 18247
# Data columns (total 63 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        18248 non-null  object
#  1   regionname                18248 non-null  object
#  2   countryname               18248 non-null  object
#  3   prodline                  18248 non-null  object
#  4   lendinginstr              18002 non-null  object
#  5   lendinginstrtype          18002 non-null  object
#  6   envassesmentcategorycode  12437 non-null  object
#  7   supplementprojectflg      18195 non-null  object
#  8   productlinetype           18248 non-null  object
#  9   projectstatusdisplay      18244 non-null  object
#  10  status                    18244 non-null  object
#  11  project_name              18248 non-null  object
#  12  boardapprovaldate         16744 non-null  datetime64[ns, UTC]
# ...

# %%
df_projects["boardapprovaldate"].dtype
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# filter the data frame for projects over 1 billion dollars
#
# count the number of unique countries in the results

# %%
df_projects[df_projects["totalamt"] > 1000000000].countryname.unique()
# Out:
# array(['Arab Republic of Egypt', 'Republic of Iraq', 'Republic of Peru',
#        'Republic of India', 'Romania', 'Republic of Poland',
#        'Republic of Indonesia', 'Republic of Kazakhstan',
#        "People's Republic of Bangladesh", 'United Mexican States',
#        'Federative Republic of Brazil', 'Republic of South Africa',
#        'Republic of Turkey', 'Hungary', 'Argentine Republic',
#        'Republic of Korea', 'Russian Federation'], dtype=object)

# %%
df_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18248 entries, 0 to 18247
# Data columns (total 63 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        18248 non-null  object
#  1   regionname                18248 non-null  object
#  2   countryname               18248 non-null  object
#  3   prodline                  18248 non-null  object
#  4   lendinginstr              18002 non-null  object
#  5   lendinginstrtype          18002 non-null  object
#  6   envassesmentcategorycode  12437 non-null  object
#  7   supplementprojectflg      18195 non-null  object
#  8   productlinetype           18248 non-null  object
#  9   projectstatusdisplay      18244 non-null  object
#  10  status                    18244 non-null  object
#  11  project_name              18248 non-null  object
#  12  boardapprovaldate         16744 non-null  datetime64[ns, UTC]
# ...

# %% [markdown]
# #### filter or Find the columns by name

# %%
df_projects[df_projects.columns[df_projects.columns.str.lower().str.match("^project")]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18248 entries, 0 to 18247
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   projectstatusdisplay  18244 non-null  object
#  1   project_name          18248 non-null  object
#  2   projectdoc            0 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 427.8+ KB

# %% [markdown]
# way -2

# %%
df_projects.loc[:, df_projects.columns.str.lower().str.match("^project")].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18248 entries, 0 to 18247
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   projectstatusdisplay  18244 non-null  object
#  1   project_name          18248 non-null  object
#  2   projectdoc            0 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 427.8+ KB

# %%
print(df_projects.columns)
# Out:
# Index(['id', 'regionname', 'countryname', 'prodline', 'lendinginstr',
#        'lendinginstrtype', 'envassesmentcategorycode', 'supplementprojectflg',
#        'productlinetype', 'projectstatusdisplay', 'status', 'project_name',
#        'boardapprovaldate', 'board_approval_month', 'closingdate',
#        'lendprojectcost', 'ibrdcommamt', 'idacommamt', 'totalamt', 'grantamt',
#        'borrower', 'impagency', 'url', 'projectdoc ', 'majorsector_percent ',
#        'sector1', 'sector2', 'sector3', 'sector4', 'sector5', 'sector',
#        'mjsector1', 'mjsector2', 'mjsector3', 'mjsector4', 'mjsector5',
#        'mjsector', 'theme1', 'theme2', 'theme3', 'theme4', 'theme5', 'theme ',
#        'goal', 'financier', 'mjtheme1name', 'mjtheme2name', 'mjtheme3name',
#        'mjtheme4name', 'mjtheme5name', 'location', 'GeoLocID', 'GeoLocName',
#        'Latitude', 'Longitude', 'Country', 'Unnamed: 56', 'approvalyear',
#        'approvalday', 'approvalweekday', 'closingyear', 'closingday',
# ...

# %%
df_projects.columns = df_projects.columns.str.strip()

# %%
df_projects[["projectstatusdisplay", "project_name", "projectdoc"]]
# Out:
#       projectstatusdisplay                                       project_name  \
# 0                   Active   Creating a Trade in Value-Added Database for ...
# 1                   Active                       Productive Inclusion Project
# 2                   Active  Additional Financing for Health Sector Support...
# 3                   Active  Public-Private Partnerships and Public Investm...
# 4                   Active                          Nigeria For Women Project
# ...                    ...                                                ...
# 18243               Closed                       Power and Irrigation Project
# 18244               Closed                     Steel Mill and Railway Project
# 18245               Closed                    Post War Reconstruction Project
# 18246               Closed                    Post-war Reconstruction Project
# 18247               Closed                             Reconstruction Project
#
#        projectdoc
# ...

# %%
df_projects["lendinginstr"].value_counts()
# Out:
# lendinginstr
# Specific Investment Loan                   7626
# Investment Project Financing               3339
# Technical Assistance Loan                  1620
# Sector Investment and Maintenance Loan     1260
# Development Policy Lending                  874
# Financial Intermediary Loan                 806
# Emergency Recovery Loan                     576
# Structural Adjustment Loan                  541
# Adaptable Program Loan                      517
# Sector Adjustment Loan                      365
# Learning and Innovation Loan                172
# Program-for-Results                         133
# Programmatic Structural Adjustment Loan      51
# UNIDENTIFIED                                 45
# Poverty Reduction Support Credit             40
# Rehabilitation Loan                          22
# Debt and Debt Service Reduction Loan         13
# Special Structural Adjustment Loan            2
# Name: count, dtype: int64

# %%
sector = df_projects.copy()
sector = sector[['project_name', 'lendinginstr', 'sector1', 'sector2', 'sector3', 'sector4', 'sector5', 'sector',
          'mjsector1', 'mjsector2', 'mjsector3', 'mjsector4', 'mjsector5',
          'mjsector', 'theme1', 'theme2', 'theme3', 'theme4', 'theme5', 'theme',
          'goal', 'financier', 'mjtheme1name', 'mjtheme2name', 'mjtheme3name',
          'mjtheme4name', 'mjtheme5name']]

# %%
sector.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18248 entries, 0 to 18247
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   project_name  18248 non-null  object
#  1   lendinginstr  18002 non-null  object
#  2   sector1       18248 non-null  object
#  3   sector2       9527 non-null   object
#  4   sector3       6487 non-null   object
#  5   sector4       4376 non-null   object
#  6   sector5       2713 non-null   object
#  7   sector        17610 non-null  object
#  8   mjsector1     0 non-null      float64
#  9   mjsector2     0 non-null      float64
#  10  mjsector3     0 non-null      float64
#  11  mjsector4     0 non-null      float64
#  12  mjsector5     0 non-null      float64
#  13  mjsector      17610 non-null  object
#  14  theme1        18248 non-null  object
#  15  theme2        9853 non-null   object
#  16  theme3        7484 non-null   object
#  17  theme4        5234 non-null   object
# ...

# %%
sector["sector1"].value_counts()
# Out:
# sector1
# !$!0                                                                   638
# (Historic)Highways!$!100!$!TH                                          477
# Central Government (Central Agencies)!$!100!$!BC                       413
# (Historic)Agriculture adjustment!$!100!$!AA                            394
# Irrigation and Drainage!$!100!$!AI                                     342
#                                                                       ...
# Agricultural markets; commercialization and agri-business!$!70!$!YA      1
# Renewable energy!$!75!$!LE                                               1
# (Historic)Agriculture adjustment!$!60!$!AA                               1
# (Historic)Tourism!$!100!$!QQ                                             1
# (Historic)Rural roads!$!50!$!TR                                          1
# Name: count, Length: 3060, dtype: int64

# %% [markdown]
# find out how many % values are missing

# %%
100 * sector.isna().sum() / sector.shape[0]
# Out:
# project_name      0.000000
# lendinginstr      1.348093
# sector1           0.000000
# sector2          47.791539
# sector3          64.450899
# sector4          76.019290
# sector5          85.132617
# sector            3.496274
# mjsector1       100.000000
# mjsector2       100.000000
# mjsector3       100.000000
# mjsector4       100.000000
# mjsector5       100.000000
# mjsector          3.496274
# theme1            0.000000
# theme2           46.005042
# theme3           58.987286
# theme4           71.317405
# theme5           83.954406
# theme           100.000000
# goal             33.510522
# financier        61.310829
# mjtheme1name    100.000000
# mjtheme2name    100.000000
# mjtheme3name    100.000000
# mjtheme4name    100.000000
# mjtheme5name    100.000000
# dtype: float64

# %% [markdown]
# Create a list of the unique values in sector1.

# %%
uniquesectos1 = sector["sector1"].sort_values().unique()
print(uniquesectos1)
# Out:
# ['!$!0' '(Historic)Agency reform!$!50!$!AG'
#  '(Historic)Agricultural credit!$!100!$!AC' ...
#  'Workforce Development and Vocational Education!$!96!$!EW'
#  'Workforce Development and Vocational Education!$!98!$!EW'
#  'Workforce Development and Vocational Education!$!99!$!EW']

# %% [markdown]
# TODO: In the sector1 variable, replace the string '!$10' with nan
#
# TODO: In the sector1 variable, remove the last 10 or 11 characters from the sector1 variable.
#
# TODO: Remove the string '(Historic)' from the sector1 variable

# %%
import numpy as np
sector["sector1"] = sector["sector1"].replace('!$!0', np.nan)
sector["sector1"].value_counts()
# Out:
# sector1
# (Historic)Highways!$!100!$!TH                                          477
# Central Government (Central Agencies)!$!100!$!BC                       413
# (Historic)Agriculture adjustment!$!100!$!AA                            394
# Irrigation and Drainage!$!100!$!AI                                     342
# (Historic)Financial sector development!$!100!$!FS                      264
#                                                                       ...
# Other Water Supply; Sanitation and Waste Management!$!29!$!WZ            1
# Agricultural markets; commercialization and agri-business!$!70!$!YA      1
# Renewable energy!$!75!$!LE                                               1
# (Historic)Agriculture adjustment!$!60!$!AA                               1
# (Historic)Tourism!$!100!$!QQ                                             1
# Name: count, Length: 3059, dtype: int64

# %%
sector["sector1"] = sector["sector1"].replace('!.+','',regex=True)
sector["sector1"].value_counts()
# Out:
# sector1
# Central Government (Central Agencies)                    1644
# Health                                                    782
# Social Protection                                         767
# Irrigation and Drainage                                   624
# Other Agriculture; Fishing and Forestry                   589
#                                                          ...
# (Historic)Agency reform                                     1
# (Historic)Environment adjustment                            1
# (Historic)Population; health and nutrition adjustment       1
# (Historic)Decentralization                                  1
# (Historic)HIV/AIDS                                          1
# Name: count, Length: 158, dtype: int64

# %%
sector["sector1"] = sector["sector1"].replace('^(\(Historic\))', '', regex=True)
sector["sector1"].value_counts()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# C:\Users\User 1\AppData\Local\Temp\ipykernel_5124\2224470691.py:1: SyntaxWarning: invalid escape sequence '\('
#   sector["sector1"] = sector["sector1"].replace('^(\(Historic\))', '', regex=True)
# sector1
# Central Government (Central Agencies)          1644
# Health                                          782
# Social Protection                               767
# Irrigation and Drainage                         624
# Other Agriculture; Fishing and Forestry         589
#                                                ...
# Agency reform                                     1
# Environment adjustment                            1
# Population; health and nutrition adjustment       1
# Decentralization                                  1
# HIV/AIDS                                          1
# Name: count, Length: 155, dtype: int64

# %% [markdown]
# find the unique values after cleaning

# %%
len(list(sector["sector1"].unique()))
# Out:
# 156

# %% [markdown]
# find out how many % values are missing after cleaning

# %%
100 * sector["sector1"].isna().sum() / sector.shape[0]
# Out:
# np.float64(3.4962735642262164)

# %% [markdown]
# Now there are 156 unique categorical values. That's better than 3060. If you were going to use this data with a supervised learning machine model, you could try converting these 156 values to dummy variables. You'd still have to train and test a model to see if those are good features.

# %% [markdown]
# `pd.get_dummies()` is a go-to tool in **pandas** for turning categorical data into a numerical format that machine learning algorithms can work with. Most ML models don’t understand text, so we “dummy encode” categories into binary (0/1) columns.
#
# ### 📦 Why use `get_dummies`?
# Suppose you have a DataFrame like this:
#
# ```python
# df = pd.DataFrame({
#     'City': ['Mumbai', 'Delhi', 'Bangalore', 'Delhi']
# })
# ```
#
# When you use:
# ```python
# pd.get_dummies(df, columns=['City'])
# ```
#
# You get:
# ```
#    City_Bangalore  City_Delhi  City_Mumbai
# 0               0           0            1
# 1               0           1            0
# 2               1           0            0
# 3               0           1            0
# ```
#
# Each category becomes its own column, with `1` where that category was present.
#
# ---
#
# ### 🧰 Common Parameters of `pd.get_dummies()`
#
# | Parameter         | What it does                                                                 |
# |------------------|------------------------------------------------------------------------------|
# | `data`           | Your original DataFrame or Series                                            |
# | `prefix`         | Adds a prefix to new columns                                                 |
# | `prefix_sep`     | Separator between prefix and category name (default is `_`)                  |
# | `columns`        | List of columns to encode                                                    |
# | `drop_first`     | If `True`, removes the first category (helps avoid dummy variable trap)      |
# | `dtype`          | Lets you set the data type of new columns (e.g., `np.int8` to save space)    |
# | `dummy_na`       | If `True`, adds a column for `NaN` values                                    |
#
# ---
#
# ### 💡 When to use
# - When you need to **feed categorical data** into scikit-learn models (like Logistic Regression, Decision Trees, etc.).
# - When performing **statistical modeling** and need clean, numeric inputs.
# - When visualizing or summarizing categorical patterns in a tabular format.

# %% [markdown]
# In this next exercise, use the pandas pd.get_dummies() method to create dummy variables. Then use the concat() method to concatenate the dummy variables to a dataframe that contains the project totalamt variable and the project year from the boardapprovaldate.

# %%
dummies = pd.DataFrame(pd.get_dummies(sector["sector1"]))

df_projects["year"] = df_projects["boardapprovaldate"].dt.year
df = df_projects[["totalamt", "year"]]
df_final = pd.concat([df,dummies], axis=1)
df_final.head()
# Out:
#     totalamt    year  Adult; Basic and Continuing Education  Agency reform  \
# 0          0  2018.0                                  False          False
# 1  200000000  2018.0                                  False          False
# 2   58330000  2018.0                                  False          False
# 3   20000000  2018.0                                  False          False
# 4  100000000  2018.0                                  False          False
#
#    Agricultural Extension; Research; and Other Support Activities  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Agricultural credit  Agricultural extension  \
# 0                False                   False
# 1                False                   False
# ...

# %%
df_final.groupby("year").sum(numeric_only=True)
# Out:
#            totalamt  Adult; Basic and Continuing Education  Agency reform  \
# year
# 1947.0    497000000                                      0              0
# 1948.0     24000000                                      0              0
# 1949.0    208100000                                      0              0
# 1950.0    279200000                                      0              0
# 1951.0    208400000                                      0              0
# ...             ...                                    ...            ...
# 2014.0  47485020000                                      1              0
# 2015.0  45237770000                                      0              0
# 2016.0  37221230000                                      0              0
# 2017.0  44089540000                                      1              0
# 2018.0  28647550000                                      0              0
#
#         Agricultural Extension; Research; and Other Support Activities  \
# ...

# %% [markdown]
# ### Finding Outliers
